# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrenJH/Estructura_de_Datos/blob/main/Ejercicio_Cafeteria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ALGORITMO
#¿Qué resuelvo?
# - Asignar un platillo a cada cliente de la cafetería (Hay 3 tipos de platillos: Tortas, quesadillas y dobladitas) (Opcional: agregar bebidas)
#¿Qué necesito?
# - Conocer la cantidad de clientes que comerán en la cafetería

#¿Cómo lo resuelvo?
# - Pedir la cantida de clientes que comerán en la cafería
# - Colocar la misma cantidad de platillas de manera aleatoria (a cada cliente le corresponde un platillo)

# %%
import random

class Pila:
    def __init__(self):
        self.items = []

    def push(self, dato):
        self.items.append(dato)

    def pop(self):
        return self.items.pop() if not self.is_empty() else None

    def is_empty(self):
        return len(self.items) == 0

class Cola:
    def __init__(self):
        self.items = []

    def enqueue(self, dato):
        self.items.append(dato)

    def dequeue(self):
        return self.items.pop(0) if not self.is_empty() else None

    def is_empty(self):
        return len(self.items) == 0

# --- Bucle Principal del Programa ---

while True:
    try:
        # 1. Pedir la cantidad de clientes
        cantidad_clientes = int(input("¿Cuántos clientes comerán en la cafetería? "))

        if cantidad_clientes <= 0:
            print("Error: Debe haber al menos un cliente.")
            continue

        # --- Preparativos ---

        # 2. Se forman los clientes en la fila (Cola)
        fila_clientes = Cola()
        for i in range(1, cantidad_clientes + 1):
            fila_clientes.enqueue(f"Cliente {i}")

        # 3. Se preparan los platillos y se apilan (Pila)
        pila_platillos = Pila()
        tipos_de_platillo = ["Torta", "Quesadilla", "Dobladita"]
        platillos_a_preparar = [random.choice(tipos_de_platillo) for _ in range(cantidad_clientes)]
        random.shuffle(platillos_a_preparar)

        for platillo in platillos_a_preparar:
            pila_platillos.push(platillo)

        print(f"\nSe han preparado {cantidad_clientes} platillos.")
        print(f"Los clientes están formados en la fila.")

        # --- Mostrar estado antes de servir ---
        print("\n--- Estado Antes de Servir ---")
        print(f"Fila de clientes: {fila_clientes.items}")
        print(f"Pila de platillos: {pila_platillos.items}")
        print("-" * 30)

        # --- Asignación ---

        print("Comenzando a servir...\n")

        while not fila_clientes.is_empty():
            cliente_atendido = fila_clientes.dequeue()
            platillo_servido = pila_platillos.pop()

            print(f"{cliente_atendido} recibe: {platillo_servido}")

        # --- Mostrar estado después de servir ---
        print("\n--- Estado Final ---")
        print(f"Fila de clientes: {fila_clientes.items}")
        print(f"Pila de platillos: {pila_platillos.items}")
        print("Todos los clientes han sido atendidos.")

    except ValueError:
        print("Error: Por favor, ingresa un número entero válido.")

    # --- Preguntar si se desea repetir la simulación ---
    otra_vez = input("\n¿Deseas realizar otra simulación? (s/n): ")
    if otra_vez.lower() != 's':
        print("\n ¡Gracias por visitar la cafetería!")
        break
    print("\n" + "="*30 + "\n")
# Out:
# ¿Cuántos clientes comerán en la cafetería? 5
#
# Se han preparado 5 platillos.
# Los clientes están formados en la fila.
#
# --- Estado Antes de Servir ---
# Fila de clientes (orden de llegada): ['Cliente 1', 'Cliente 2', 'Cliente 3', 'Cliente 4', 'Cliente 5']
# Pila de platillos (último preparado, primero en salir): ['Torta', 'Quesadilla', 'Dobladita', 'Torta', 'Torta']
# ------------------------------
# Comenzando a servir...
#
# Cliente 1 recibe: Torta
# Cliente 2 recibe: Torta
# Cliente 3 recibe: Dobladita
# Cliente 4 recibe: Quesadilla
# Cliente 5 recibe: Torta
#
# --- Estado Final ---
# Fila de clientes: []
# Pila de platillos: []
# Todos los clientes han sido atendidos.
#
# ¿Deseas realizar otra simulación? (s/n): s
#
# ==============================
#
# ¿Cuántos clientes comerán en la cafetería? 10
#
# Se han preparado 10 platillos.
# Los clientes están formados en la fila.
#
# --- Estado Antes de Servir ---
# Fila de clientes (orden de llegada): ['Cliente 1', 'Cliente 2', 'Cliente 3', 'Cliente 4', 'Cliente 5', 'Cliente 6', 'Cliente 7', 'Cliente 8', 'Cliente 9', 'Cliente 10']
# Pila de platillos (último preparado, primero en salir): ['Dobladita', 'Quesadilla', 'Torta', 'Dobladita', 'Torta', 'Torta', 'Quesadilla', 'Torta', 'Torta', 'Quesadilla']
# ------------------------------
# Comenzando a servir...
#
# Cliente 1 recibe: Quesadilla
# Cliente 2 recibe: Torta
# Cliente 3 recibe: Torta
# Cliente 4 recibe: Quesadilla
# Cliente 5 recibe: Torta
# Cliente 6 recibe: Torta
# Cliente 7 recibe: Dobladita
# Cliente 8 recibe: Torta
# Cliente 9 recibe: Quesadilla
# Cliente 10 recibe: Dobladita
#
# --- Estado Final ---
# Fila de clientes: []
# Pila de platillos: []
# Todos los clientes han sido atendidos.
#
# ¿Deseas realizar otra simulación? (s/n): n
#
# Gracias por visitar la cafetería. ¡Adiós!
